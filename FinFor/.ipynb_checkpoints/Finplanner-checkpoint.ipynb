# %%
"""
Finplanner
~~~~~~~~~~~~~~~~

This module provides the following -
1) The first will be a personal finance planner that will allow users to visualize their savings composed by 
investments in shares and cryptocurrencies to assess if they have enough money as an emergency fund.

2) The second tool will be a retirement planning tool that will use the Alpaca API to fetch historical closing 
prices for a retirement portfolio composed of stocks and bonds, then run Monte Carlo simulations to project the 
portfolio performance at 30 years. You will then use the Monte Carlo data to calculate the expected portfolio returns 
given a specific initial investment amount.

The module consumes following APIS--

The Alpaca Markets API will be used to pull historical stocks and bonds information.
The Alternative Free Crypto API will be used to retrieve Bitcoin and Ethereum prices.
 

It provides the following output - 

- Savings Health Analysis based on the Initial income.
- Use Montecarlo simulation to project the portfolio performance at 30 years and provide 
  95% confidence interval for the outcome.

"""
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sn
import quandl as quandl
import os
import dotenv
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
from alpaca_trade_api.rest import TimeFrame
import requests
import json
from MCForecastTools import MCSimulation # #Import Monte Carlo module to be used for Retirement planning simulations.
# %matplotlib inline

# %%
# Obtain Keys to connect to ALPACA API
load_dotenv() # True
CONSUMER_KEY = os.environ.get("ALPACA_API_KEY")

CONSUMER_SECRET_KEY = os.environ.get("ALPACA_SECRET_KEY")
quandl.ApiConfig.api_key = os.environ.get("QUANTA_API_KEY")

# %%
#mydata = quandl.get("FRED/GDP", start_date='2019-12-31', end_date='2020-9-26')
#quandl.get("WIKI/AMD")

# %%
# Initialize ALPACA API
ALPACA_URL='https://paper-api.alpaca.markets'
alpaca_api = tradeapi.REST(CONSUMER_KEY, CONSUMER_SECRET_KEY, ALPACA_URL, api_version='v2')

# %%
#The average household income for each member of the credit union is $12,000.
avg_inc=12000
#Every union member has a savings portfolio composed of cryptocurrencies, stocks and bonds:
#Assume the following amount of crypto assets: 1.2 BTC and 5.3 ETH.
#Assume the following amount of shares in stocks and bonds: 50 SPY (stocks) and 200 AGG (bonds).
BTC=1.2
ETH=5.3
SPY_stock=50
AGG_bonds=200
monthly_income=12000

# %%
BTC_price=0.0
ETH_price=0.0
# Crypto API URLs
btc_url = "https://api.alternative.me/v2/ticker/Bitcoin/?convert=CAD"
eth_url = "https://api.alternative.me/v2/ticker/Ethereum/?convert=CAD"

# %%
def getResponse(url):
    """ # Function to read http URL and store the output of the file content into a json format
         :param url - URL

    """
    response= requests.get(url)
    
    
    if(response.status_code==200):
        json_response = response.json()
        #jsonData = json.dumps(json_response, indent=4, sort_keys=True)
    else:
        print("Error receiving data", response.status_code)
    return json_response

# %%
# Call the Crypto API and store respnse.
btc_response=getResponse(btc_url)

# %%
#Validate data
print(json.dumps(btc_response, indent=4, sort_keys=True))
# Out:
# {
#     "data": {
#         "1": {
#             "circulating_supply": 18920000,
#             "id": 1,
#             "last_updated": 1641342234,
#             "max_supply": 21000000,
#             "name": "Bitcoin",
#             "quotes": {
#                 "CAD": {
#                     "market_cap": 1113441585758.59,
#                     "percent_change_1h": 0.224788990313109,
#                     "percent_change_24h": -0.490167129462961,
#                     "percent_change_7d": -3.27151566652166,
#                     "price": 58660.5948,
#                     "volume_24h": 31796184176.9468
#                 },
#                 "USD": {
#                     "market_cap": 876242689666,
#                     "percent_change_1h": 0.224788990313109,
#                     "percent_change_24h": -0.490167129462961,
#                     "percent_change_7d": -3.27151566652166,
#                     "percentage_change_1h": 0.224788990313109,
# ...

# %%
# Obtain price in USD from the json output.
btc_response['data']['1']['quotes']['USD']['price']
# Out:
# 46164.0

# %%
# Call the Crypto API and store respnse.
eth_response=getResponse(eth_url)

# %%
#Validate data
print(json.dumps(eth_response, indent=4, sort_keys=True))
# Out:
# {
#     "data": {
#         "1027": {
#             "circulating_supply": 119025301,
#             "id": 1027,
#             "last_updated": 1641342273,
#             "max_supply": 0,
#             "name": "Ethereum",
#             "quotes": {
#                 "CAD": {
#                     "market_cap": 577627586852.144,
#                     "percent_change_1h": 0.0010064194699839,
#                     "percent_change_24h": 0.983385316591634,
#                     "percent_change_7d": -0.0001099423994456,
#                     "price": 4838.012352,
#                     "volume_24h": 17661338700.4044
#                 },
#                 "USD": {
#                     "market_cap": 454574318763,
#                     "percent_change_1h": 0.0010064194699839,
#                     "percent_change_24h": 0.983385316591634,
#                     "percent_change_7d": -0.0001099423994456,
#                     "percentage_change_1h": 0.0010064194699839,
# ...

# %%
def get_value(json_input, lookup_key):
    """ # Function to read json output of URL call and iterate recursively to find the USD price of the crypto currency.
         :param json_input - json output variable
         :param lookup key, in this case "USD"
         
    """
    value = list(json_iterator(json_input, lookup_key))
    val = value[0] if value else None
        #print(f'lookup_key -> value : {val}')
    return val
def json_iterator(json_input, lookup_key):
    if isinstance(json_input, dict):
        for k, v in json_input.items():
            #print(f'{k} -- {v}')
            if k == lookup_key:
                yield v
            else:
                yield from json_iterator(v, lookup_key)
    elif isinstance(json_input, list):
        for item in json_input:
            yield from json_iterator(item, lookup_key)

# %%
#Obtain USD price for both crypto currency
BTC_price=get_value(btc_response,'USD')['price']
ETH_price=get_value(eth_response,'USD')['price']

# %%
print(BTC_price)
# Out:
# 46164.0

# %%
print(ETH_price)
# Out:
# 3807.36

# %%
print(f"The current value of your {BTC} BTC is ${BTC_price*BTC:0.2f}")
print(f"The current value of your {ETH} ETH is ${ETH_price*ETH:0.2f}")
# Out:
# The current value of your 1.2 BTC is $55396.80
# The current value of your 5.3 ETH is $20179.01

# %%
#Calculate and print crypto portfolio.
Crypto_portfolio=round((BTC_price*BTC + ETH_price*ETH),2)
print(Crypto_portfolio)
# Out:
# 75575.81

# %%
# Call ALPACA API to get data for ticker symbols.
# Format current date as ISO format
NY = 'America/New_York'

edate = dt.date.today()
start=pd.Timestamp('2020-08-01', tz=NY).isoformat()
end=pd.Timestamp(edate, tz=NY).isoformat()
# Set the tickers
tickers = ["AGG", "SPY"]
# Set timeframe to '1D' for Alpaca API, 
# Get current closing prices for SPY and AGG
# (use a limit=1000 parameter to call the most recent 1000 days of data)
alpaca_api.get_barset(tickers, '1D', start=start, end=end, limit=1000).df
# Out:
#                               AGG                                         \
#                              open      high       low    close    volume
# time
# 2020-08-03 00:00:00-04:00  119.37  119.4000  119.1903  119.400  17837420
# 2020-08-04 00:00:00-04:00  119.42  119.6300  119.4200  119.630  21512268
# 2020-08-05 00:00:00-04:00  119.39  119.4900  119.3100  119.400  34175883
# 2020-08-06 00:00:00-04:00  119.62  119.7300  119.5300  119.580   9009216
# 2020-08-07 00:00:00-04:00  119.66  119.7300  119.3950  119.445   8830420
# ...                           ...       ...       ...      ...       ...
# 2021-12-29 00:00:00-05:00  113.99  114.0500  113.8100  113.870   5712959
# 2021-12-30 00:00:00-05:00  113.99  114.1300  113.8300  114.120   5044053
# 2021-12-31 00:00:00-05:00  114.15  114.3100  114.0600  114.090   6557778
# 2022-01-03 00:00:00-05:00  113.67  113.6753  113.3100  113.310   8906643
# 2022-01-04 00:00:00-05:00  113.22  113.3000  113.0750  113.290   7615698
#
# ...

# %%
#Create dataframe to store API output
alpaca_df=alpaca_api.get_barset(tickers, '1D', start=start, end=end, limit=1000).df

# %%
#Get the current closing prices for SPY and AGG.
agg_close_price=alpaca_df['AGG'].iloc[-1]['close']
spy_close_price=alpaca_df['SPY'].iloc[-1]['close']
# Print AGG and SPY close prices
print(f"Current AGG closing price: ${agg_close_price}")
print(f"Current SPY closing price: ${spy_close_price}")
# Out:
# Current AGG closing price: $113.29
# Current SPY closing price: $477.51

# %%
# Compute the current value of shares
my_spy_value=SPY_stock*spy_close_price
my_agg_value=AGG_bonds*agg_close_price

# Print current value of shares
print(f"The current value of your {SPY_stock} SPY shares is ${my_spy_value:0.2f}")
print(f"The current value of your {AGG_bonds} AGG shares is ${my_agg_value:0.2f}")
# Out:
# The current value of your 50 SPY shares is $23875.50
# The current value of your 200 AGG shares is $22658.00

# %%
#Calculate and print share and bonds portfolio.
Shares_portfolio=round((my_spy_value + my_agg_value),2)
print(Shares_portfolio)
# Out:
# 46533.5

# %% [markdown]
# #### Savings Health Analysis
# Assess the financial health of the credit union's members.

# %%
#create a DataFrame called df_savings with two rows. Store the total value in dollars of the crypto assets in the first row and the total value of the shares in the second row.
details = {
    'crypto' : [Crypto_portfolio],
    'shares' : [Shares_portfolio]
}

portfolio_df = pd.DataFrame.from_dict(details, orient = 'index',columns=['amount'])

# %%
portfolio_df
# Out:
#           amount
# crypto  75575.81
# shares  46533.50

# %%
#plot a pie chart to visualize the composition of personal savings
portfolio_df.plot.pie(y='amount')

# %%
#Emergency Fund calculation
Emergency_fund=monthly_income*3

# %%
def financial_health(portfolio_df,Emergency_fund):
    """ # Function to read portfolio data and return the financial health of savings.
         :param portfolio_df - portfolio dataframe containing crypto and share&bond data.
         :param Emergency_fund - Threshold for emergency fund against which the health shall be calculated.

    """
    portfolio_fund=portfolio_df.sum().values[0]
    if portfolio_fund > Emergency_fund:
        print("Congratulations! You have enough money in your emergency fund.")
    elif portfolio_fund < Emergency_fund:
        print(f"Caution! You are short of reaching your emergency fund target. Gap is: ${Emergency_fund - portfolio_fund}")
    elif portfolio_fund == Emergency_fund:
        print("Congratulations! You have reached your financial target.")

# %%
#Calculate and print Financial Health of Savings.
financial_health(portfolio_df,Emergency_fund)
# Out:
# Congratulations! You have enough money in your emergency fund.

# %% [markdown]
# #### Part 2 - Retirement Planning

# %%
#Set variables to store stock, bond, weightage of each and the simulation run time period.

stock_basket=.40
bond_basket=.60
weights =[bond_basket,stock_basket]
num_years=30

# %%
# Format current date as ISO format
NY = 'America/New_York'

edate = dt.date.today()
start=pd.Timestamp('2016-05-01', tz=NY).isoformat()
#print(start)
end=pd.Timestamp(edate, tz=NY).isoformat()
#print(end)
#end = pd.Timestamp('2016-10-16', tz='America/New_York').isoformat()
# Set the tickers
tickers = ["AGG", "SPY"]
# Set timeframe to '1D' for Alpaca API, 
timeframe = "1D"
# Get current closing prices for SPY and AGG
# (use a limit=1000 parameter to call the most recent 1000 days of data)
Five_year_data=alpaca_api.get_barset(tickers, timeframe, start=start, end=end, limit=1000).df

# %%
#Validate Data obtained from ALPACA for the portfolio.
Five_year_data.head()
# Out:
#                               AGG                                        \
#                              open      high      low   close     volume
# time
# 2018-01-16 00:00:00-05:00  108.87  108.9800  108.715  108.76  6011248.0
# 2018-01-17 00:00:00-05:00  108.73  108.8390  108.620  108.65  2880481.0
# 2018-01-18 00:00:00-05:00  108.43  108.5250  108.350  108.38  2681682.0
# 2018-01-19 00:00:00-05:00  108.40  108.4000  108.140  108.15  2751607.0
# 2018-01-22 00:00:00-05:00  108.22  108.2999  108.110  108.16  3020514.0
#
#                               SPY
#                              open    high     low   close      volume
# time
# 2018-01-16 00:00:00-05:00     NaN     NaN     NaN     NaN         NaN
# 2018-01-17 00:00:00-05:00  278.04  280.05  277.19  279.61  62162956.0
# 2018-01-18 00:00:00-05:00  279.50  279.96  278.58  279.18  57402163.0
# 2018-01-19 00:00:00-05:00  279.80  280.40  279.14  280.38  55178145.0
# ...

# %%
#Configure and execute a Monte Carlo Simulation of 500 runs and 30 years for the 40/60 portfolio.
y30_4060_20_mc=MCSimulation(Five_year_data, weights=weights, num_simulation=1000, num_trading_days=252*num_years)
# Print the simulation input data
y30_4060_20_mc.portfolio_data.head()
# Out:
#                               AGG                                        \
#                              open      high      low   close     volume
# time
# 2018-01-16 00:00:00-05:00  108.87  108.9800  108.715  108.76  6011248.0
# 2018-01-17 00:00:00-05:00  108.73  108.8390  108.620  108.65  2880481.0
# 2018-01-18 00:00:00-05:00  108.43  108.5250  108.350  108.38  2681682.0
# 2018-01-19 00:00:00-05:00  108.40  108.4000  108.140  108.15  2751607.0
# 2018-01-22 00:00:00-05:00  108.22  108.2999  108.110  108.16  3020514.0
#
#                                            SPY                          \
#                           daily_return    open    high     low   close
# time
# 2018-01-16 00:00:00-05:00          NaN     NaN     NaN     NaN     NaN
# 2018-01-17 00:00:00-05:00    -0.001011  278.04  280.05  277.19  279.61
# 2018-01-18 00:00:00-05:00    -0.002485  279.50  279.96  278.58  279.18
# 2018-01-19 00:00:00-05:00    -0.002122  279.80  280.40  279.14  280.38
# ...

# %%
# Run a Monte Carlo simulation to forecast 30 years cumulative returns
y30_4060_20_mc.plot_simulation()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# ...

# %%
# Plot probability distribution and confidence intervals
y30_4060_20_mc.plot_distribution()

# %%
# Fetch summary statistics from the Monte Carlo simulation results
# YOUR CODE HERE!
y30_4060_20=y30_4060_20_mc.summarize_cumulative_return()
# Print summary statistics
print(y30_4060_20)
# Out:
# count           1000.000000
# mean               8.450486
# std                4.586139
# min                1.718413
# 25%                5.286547
# 50%                7.529068
# 75%               10.527439
# max               47.055531
# 95% CI Lower       2.824508
# 95% CI Upper      19.035055
# Name: 7560, dtype: float64

# %%
# Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $20,000 investments stocks
initial_inv_20=20000
# Print results
print(f"There is a 95% chance that an initial investment of ${initial_inv_20} in the portfolio over the next 30 years will end within in the range of {round(y30_4060_20[8]*initial_inv_20,2)} and {round(y30_4060_20[9]*initial_inv_20,2)}.")
# Out:
# There is a 95% chance that an initial investment of $20000 in the portfolio over the next 30 years will end within in the range of 56490.17 and 380701.11.

# %%
#Calculate the expected portfolio return at the 95% lower and upper confidence intervals based on a 50% increase in the initial investment.
New_inv=initial_inv_20 * 1.5
print(f"There is a 95% chance that an initial investment of ${New_inv} in the portfolio over the next 30 years will end within in the range of {round(y30_4060_20[8]*New_inv,2)} and {round(y30_4060_20[9]*New_inv,2)}.")
# Out:
# There is a 95% chance that an initial investment of $30000.0 in the portfolio over the next 30 years will end within in the range of 84735.25 and 571051.66.

# %% [markdown]
# ###Optional Challenge - Early Retirement
# ######Try adjusting the portfolio to either include more risk (a higher stock than bond ratio) or to have a
# ######larger initial investment and rerun the retirement analysis to see what it would take to retire in 5 or 10 years
# ######instead of 30!

# %%
#Configure and execute a Monte Carlo Simulation of 500 runs and 5 years for the 60/40 portfolio.
#Set variables to store stock, bond, weightage of each and the simulation run time period.

stock_basket=.60
bond_basket=.40
weights =[bond_basket,stock_basket]
initial_inv_20=20000
num_years=5
y05_6040_20_mc=MCSimulation(Five_year_data, weights=weights, num_simulation=1000, num_trading_days=252*num_years)
# Print the simulation input data
y05_6040_20_mc.portfolio_data.head()
# Out:
#                               AGG                                        \
#                              open      high      low   close     volume
# time
# 2018-01-16 00:00:00-05:00  108.87  108.9800  108.715  108.76  6011248.0
# 2018-01-17 00:00:00-05:00  108.73  108.8390  108.620  108.65  2880481.0
# 2018-01-18 00:00:00-05:00  108.43  108.5250  108.350  108.38  2681682.0
# 2018-01-19 00:00:00-05:00  108.40  108.4000  108.140  108.15  2751607.0
# 2018-01-22 00:00:00-05:00  108.22  108.2999  108.110  108.16  3020514.0
#
#                                            SPY                          \
#                           daily_return    open    high     low   close
# time
# 2018-01-16 00:00:00-05:00          NaN     NaN     NaN     NaN     NaN
# 2018-01-17 00:00:00-05:00    -0.001011  278.04  280.05  277.19  279.61
# 2018-01-18 00:00:00-05:00    -0.002485  279.50  279.96  278.58  279.18
# 2018-01-19 00:00:00-05:00    -0.002122  279.80  280.40  279.14  280.38
# ...

# %%
# Run a Monte Carlo simulation to forecast five years cumulative returns
y05_6040_20_mc.plot_simulation()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# ...

# %%
# Plot probability distribution and confidence intervals
y05_6040_20_mc.plot_distribution()

# %%
# Fetch summary statistics from the Monte Carlo simulation results
# YOUR CODE HERE!
y05_6040_20=y05_6040_20_mc.summarize_cumulative_return()
# Print summary statistics
print(y05_6040_20)
# Out:
# count           1000.000000
# mean               1.648357
# std                0.494187
# min                0.599362
# 25%                1.283654
# 50%                1.562507
# 75%                1.934388
# max                3.841216
# 95% CI Lower       0.904473
# 95% CI Upper       2.788124
# Name: 1260, dtype: float64

# %%
# Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $20,000 investments stocks

# Print results
print(f"There is a 95% chance that an initial investment of ${initial_inv_20} in the portfolio over the next 5 years will end within in the range of {round(y05_6040_20[8]*initial_inv_20,2)} and {round(y05_6040_20[9]*initial_inv_20,2)}.")
# Out:
# There is a 95% chance that an initial investment of $20000 in the portfolio over the next 5 years will end within in the range of 18089.47 and 55762.47.

# %%
#Configure and execute a Monte Carlo Simulation of 500 runs and 10 years for the 60/40 portfolio.
#Set variables to store stock, bond, weightage of each and the simulation run time period.

stock_basket=.60
bond_basket=.40
weights =[bond_basket,stock_basket]
initial_inv_20=20000
num_years=10
y10_6040_20_mc=MCSimulation(Five_year_data, weights=weights, num_simulation=1000, num_trading_days=252*num_years)
# Print the simulation input data
y10_6040_20_mc.portfolio_data.head()
# Out:
#                               AGG                                        \
#                              open      high      low   close     volume
# time
# 2018-01-16 00:00:00-05:00  108.87  108.9800  108.715  108.76  6011248.0
# 2018-01-17 00:00:00-05:00  108.73  108.8390  108.620  108.65  2880481.0
# 2018-01-18 00:00:00-05:00  108.43  108.5250  108.350  108.38  2681682.0
# 2018-01-19 00:00:00-05:00  108.40  108.4000  108.140  108.15  2751607.0
# 2018-01-22 00:00:00-05:00  108.22  108.2999  108.110  108.16  3020514.0
#
#                                            SPY                          \
#                           daily_return    open    high     low   close
# time
# 2018-01-16 00:00:00-05:00          NaN     NaN     NaN     NaN     NaN
# 2018-01-17 00:00:00-05:00    -0.001011  278.04  280.05  277.19  279.61
# 2018-01-18 00:00:00-05:00    -0.002485  279.50  279.96  278.58  279.18
# 2018-01-19 00:00:00-05:00    -0.002122  279.80  280.40  279.14  280.38
# ...

# %%
# Run a Monte Carlo simulation to forecast five years cumulative returns
y10_6040_20_mc.plot_simulation()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# ...

# %%
# Plot probability distribution and confidence intervals
y10_6040_20_mc.plot_distribution()

# %%
# Fetch summary statistics from the Monte Carlo simulation results
# YOUR CODE HERE!
y10_6040_20=MC_even_dist.summarize_cumulative_return()
# Print summary statistics
print(y10_6040_20)
# Out:
# count           1000.000000
# mean               1.639550
# std                0.486746
# min                0.707175
# 25%                1.296882
# 50%                1.571469
# 75%                1.900462
# max                4.308137
# 95% CI Lower       0.863707
# 95% CI Upper       2.734186
# Name: 1260, dtype: float64

# %%
# Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $20,000 investments stocks

# Print results
print(f"There is a 95% chance that an initial investment of ${initial_inv_20} in the portfolio over the next 10 years will end within in the range of {round(y10_6040_20[8]*initial_inv_20,2)} and {round(y10_6040_20[9]*initial_inv_20,2)}.")
# Out:
# There is a 95% chance that an initial investment of $20000 in the portfolio over the next 10 years will end within in the range of 17274.14 and 54683.71.

# %%
#Configure and execute a Monte Carlo Simulation of 500 runs and 5 years for higher income and 40/60 stocks to bond ratio.
#Set variables to store stock, bond, weightage of each, initial income and the simulation run time period.

stock_basket=.40
bond_basket=.60
weights =[bond_basket,stock_basket]
initial_inv_50=50000
num_years=5
y05_6040_50_mc=MCSimulation(Five_year_data, weights=weights, num_simulation=1000, num_trading_days=252*num_years)
# Print the simulation input data
y05_6040_50_mc.portfolio_data.head()
# Out:
#                               AGG                                        \
#                              open      high      low   close     volume
# time
# 2018-01-16 00:00:00-05:00  108.87  108.9800  108.715  108.76  6011248.0
# 2018-01-17 00:00:00-05:00  108.73  108.8390  108.620  108.65  2880481.0
# 2018-01-18 00:00:00-05:00  108.43  108.5250  108.350  108.38  2681682.0
# 2018-01-19 00:00:00-05:00  108.40  108.4000  108.140  108.15  2751607.0
# 2018-01-22 00:00:00-05:00  108.22  108.2999  108.110  108.16  3020514.0
#
#                                            SPY                          \
#                           daily_return    open    high     low   close
# time
# 2018-01-16 00:00:00-05:00          NaN     NaN     NaN     NaN     NaN
# 2018-01-17 00:00:00-05:00    -0.001011  278.04  280.05  277.19  279.61
# 2018-01-18 00:00:00-05:00    -0.002485  279.50  279.96  278.58  279.18
# 2018-01-19 00:00:00-05:00    -0.002122  279.80  280.40  279.14  280.38
# ...

# %%
# Run a Monte Carlo simulation to forecast five years cumulative returns
y05_6040_50_mc.plot_simulation()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# ...

# %%
# Plot probability distribution and confidence intervals
y05_6040_50_mc.plot_distribution()

# %%
# Fetch summary statistics from the Monte Carlo simulation results
# YOUR CODE HERE!
y05_6040_50=y05_6040_50_mc.summarize_cumulative_return()
# Print summary statistics
print(y05_6040_50)
# Out:
# count           1000.000000
# mean               1.416025
# std                0.295247
# min                0.767879
# 25%                1.199975
# 50%                1.379351
# 75%                1.601088
# max                2.668410
# 95% CI Lower       0.940791
# 95% CI Upper       2.060872
# Name: 1260, dtype: float64

# %%
# Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $50,000 investments stocks

# Print results
print(f"There is a 95% chance that an initial investment of ${initial_inv_50} in the portfolio over the next 5 years will end within in the range of {round(y05_6040_50[8]*initial_inv_50,2)} and {round(y05_6040_50[9]*initial_inv_50,2)}.")
# Out:
# There is a 95% chance that an initial investment of $50000 in the portfolio over the next 5 years will end within in the range of 47039.54 and 103043.6.

# %%
#Configure and execute a Monte Carlo Simulation of 500 runs and 10 years for higher income and 40/60 stocks to bond ratio.
#Set variables to store stock, bond, weightage of each, initial income and the simulation run time period.

stock_basket=.40
bond_basket=.60
weights =[bond_basket,stock_basket]
initial_inv_50=50000
num_years=10
y10_6040_50_mc=MCSimulation(Five_year_data, weights=weights, num_simulation=1000, num_trading_days=252*num_years)
# Print the simulation input data
y10_6040_50_mc.portfolio_data.head()
# Out:
#                               AGG                                        \
#                              open      high      low   close     volume
# time
# 2018-01-16 00:00:00-05:00  108.87  108.9800  108.715  108.76  6011248.0
# 2018-01-17 00:00:00-05:00  108.73  108.8390  108.620  108.65  2880481.0
# 2018-01-18 00:00:00-05:00  108.43  108.5250  108.350  108.38  2681682.0
# 2018-01-19 00:00:00-05:00  108.40  108.4000  108.140  108.15  2751607.0
# 2018-01-22 00:00:00-05:00  108.22  108.2999  108.110  108.16  3020514.0
#
#                                            SPY                          \
#                           daily_return    open    high     low   close
# time
# 2018-01-16 00:00:00-05:00          NaN     NaN     NaN     NaN     NaN
# 2018-01-17 00:00:00-05:00    -0.001011  278.04  280.05  277.19  279.61
# 2018-01-18 00:00:00-05:00    -0.002485  279.50  279.96  278.58  279.18
# 2018-01-19 00:00:00-05:00    -0.002122  279.80  280.40  279.14  280.38
# ...

# %%
# Run a Monte Carlo simulation to forecast five years cumulative returns
y10_6040_50_mc.plot_simulation()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# ...

# %%
# Plot probability distribution and confidence intervals
y10_6040_50_mc.plot_distribution()

# %%
# Fetch summary statistics from the Monte Carlo simulation results
# YOUR CODE HERE!
y10_6040_50=y10_6040_50_mc.summarize_cumulative_return()
# Print summary statistics
print(y10_6040_50)
# Out:
# count           1000.000000
# mean               1.997492
# std                0.569669
# min                0.845888
# 25%                1.606596
# 50%                1.903248
# 75%                2.300475
# max                5.375891
# 95% CI Lower       1.108936
# 95% CI Upper       3.340357
# Name: 2520, dtype: float64

# %%
# Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $50,000 investments stocks

# Print results
print(f"There is a 95% chance that an initial investment of ${initial_inv_50} in the portfolio over the next 10 years will end within in the range of {round(y10_6040_50[8]*initial_inv_50,2)} and {round(y10_6040_50[9]*initial_inv_50,2)}.")
# Out:
# There is a 95% chance that an initial investment of $50000 in the portfolio over the next 10 years will end within in the range of 55446.82 and 167017.83.

# %%
#Combining results for all combinations here -
#Configure and execute a Monte Carlo Simulation of 500 runs and 30 years for the 40/60 portfolio.
print(f"There is a 95% chance that an initial investment of ${initial_inv_20} in the portfolio over the next 30 years will end within in the range of {round(y30_4060_20[8]*initial_inv_20,2)} and {round(y30_4060_20[9]*initial_inv_20,2)}.")

#Configure and execute a Monte Carlo Simulation of 500 runs and 5 years for the 60/40 portfolio.
print(f"There is a 95% chance that an initial investment of ${initial_inv_20} in the portfolio over the next 5 years will end within in the range of {round(y05_6040_20[8]*initial_inv_20,2)} and {round(y05_6040_20[9]*initial_inv_20,2)}.")

#Configure and execute a Monte Carlo Simulation of 500 runs and 10 years for the 60/40 portfolio.
print(f"There is a 95% chance that an initial investment of ${initial_inv_20} in the portfolio over the next 10 years will end within in the range of {round(y10_6040_20[8]*initial_inv_20,2)} and {round(y10_6040_20[9]*initial_inv_20,2)}.")

#Configure and execute a Monte Carlo Simulation of 500 runs and 5 years for higher income and 40/60 stocks to bond ratio.
print(f"There is a 95% chance that an initial investment of ${initial_inv_50} in the portfolio over the next 5 years will end within in the range of {round(y05_6040_50[8]*initial_inv_50,2)} and {round(y05_6040_50[9]*initial_inv_50,2)}.")

#Configure and execute a Monte Carlo Simulation of 500 runs and 10 years for higher income and 40/60 stocks to bond ratio.
print(f"There is a 95% chance that an initial investment of ${initial_inv_50} in the portfolio over the next 10 years will end within in the range of {round(y10_6040_50[8]*initial_inv_50,2)} and {round(y10_6040_50[9]*initial_inv_50,2)}.")
# Out:
# There is a 95% chance that an initial investment of $20000 in the portfolio over the next 30 years will end within in the range of 56490.17 and 380701.11.
# There is a 95% chance that an initial investment of $20000 in the portfolio over the next 5 years will end within in the range of 18089.47 and 55762.47.
# There is a 95% chance that an initial investment of $20000 in the portfolio over the next 10 years will end within in the range of 17274.14 and 54683.71.
# There is a 95% chance that an initial investment of $50000 in the portfolio over the next 5 years will end within in the range of 47039.54 and 103043.6.
# There is a 95% chance that an initial investment of $50000 in the portfolio over the next 10 years will end within in the range of 55446.82 and 167017.83.

# %% [markdown]
# #### Overall Results -
# Looks Like the best option is 20k initial investment with 60% bonds and 40% stocks.
